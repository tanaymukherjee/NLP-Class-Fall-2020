# %% [markdown]
# # Chapter 1

# %% [markdown]
# ### You should install NLTK, import NlTK and download the NLTK Book Collection at the beginning.

# %%
# nltk.download()
## -- I have it already installed on my system so I will just import it but this is the code to install

# %%
import nltk

# %% [markdown]
# ### Question 1.1 Find the collocations in text2 from NLTK Book Collection

# %% [markdown]
# **Defintion:** A collocation is a sequence of words that occur together
# unusually often. Thus red wine is a collocation, whereas the
# wine is not. A characteristic of collocations is that they are
# resistant to substitution with words that have similar senses;
# for example, maroon wine sounds definitely odd.

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
print('; '.join(text2.collocation_list()))

# This code is to get the list of collocations from the text 5 from ntlk library and we can see the output below:
# Out:
# Colonel Brandon; Sir John; Lady Middleton; Miss Dashwood; every thing; thousand pounds; dare say; Miss Steeles; said Elinor; Miss Steele; every body; John Dashwood; great deal; Harley Street; Berkeley Street; Miss Dashwoods; young man; Combe Magna; every day; next morning

# %% [markdown]
# **Explanation:** We use the collocation_list() function on any text for which we wish to have the collocations.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 1.2 Review the discussion of conditionals in 4. Find all words in the Chat Corpus (text5) ending with the letter l. Show them in alphabetical order.

# %% [markdown]
# ***Method 1:*** I am running it for all texts while caring about the lower or upper case

# %%
sorted(w for w in set(text5) if w.endswith('l'))
# Out:
# ["'ll",
#  'Cool',
#  'Ctrl',
#  'Daniel',
#  'Devil',
#  'Evil',
#  'Girl',
#  'Hail',
#  'Hill',
#  'Kewl',
#  'LOl',
#  'Lil',
#  'Lol',
#  'Paul',
#  'Paxil',
#  'PayPal',
#  'Pearl',
#  'Phil',
#  'Rascal',
#  'Rofl',
#  'School',
#  'Steel',
#  'Still',
#  'Tell',
#  'Troll',
#  'Until',
#  'VVil',
#  'Well',
#  'Will',
#  'al',
#  'alcohol',
#  'all',
#  'anal',
#  'angel',
#  'animal',
#  'anygirl',
#  'april',
#  'asl',
#  'astral',
#  'atl',
#  'bacl',
#  'bagel',
#  'ball',
#  'barrel',
#  'bbl',
#  'beautiful',
#  'bell',
#  'betrayal',
#  'bisexual',
#  'bowl',
#  'bull',
#  'cal',
#  'call',
#  'camel',
#  'careful',
#  'cell',
#  'channel',
#  'coastal',
#  'control',
#  'controll',
#  'cool',
#  'coudl',
#  'daniel',
#  'deal',
#  'denial',
#  'denzel',
#  'devil',
#  'distrustful',
#  'dl',
#  'doll',
#  'e-mail',
#  'el',
#  'email',
#  'equal',
#  'evil',
#  'fall',
#  'fantastical',
#  'feel',
#  'financial',
#  'fl',
#  'fongul',
#  'fool',
#  'football',
#  'full',
#  'gal',
#  'genital',
#  'girl',
#  'grrl',
#  'gurrrrl',
#  'hail',
#  'hall',
#  'heal',
#  'hel',
#  'hell',
#  'helpful',
#  'hill',
#  'homosexual',
#  'howl',
#  'il',
#  'ill',
#  'individual',
#  'irl',
#  'jail',
#  'kewl',
#  'kill',
#  'kool',
#  'l',
#  'label',
#  'lawl',
#  'level',
#  'lil',
#  'll',
#  'local',
#  'lol',
#  'lolol',
#  'lolololll',
#  'lool',
#  'lysol',
#  'magical',
#  'maniacal',
#  'metal',
#  'moral',
#  'national',
#  'natural',
#  'novel',
#  'oatmeal',
#  'oatmel',
#  'occasional',
#  'official',
#  'oil',
#  'ol',
#  'original',
#  'painful',
#  'pal',
#  'partial',
#  'paxil',
#  'paypal',
#  'peel',
#  'personal',
#  'phil',
#  'physical',
#  'pmsl',
#  'political',
#  'poll',
#  'pool',
#  'ppl',
#  'ppolitical',
#  'pull',
#  'quarrel',
#  'real',
#  'recall',
#  'refill',
#  'reschedual',
#  'rofl',
#  'roll',
#  'school',
#  'scroll',
#  'sell',
#  'sexual',
#  'shall',
#  'shell',
#  'shopgirl',
#  'small',
#  'smell',
#  'soul',
#  'special',
#  'spell',
#  'steal',
#  'still',
#  'tail',
#  'tall',
#  'technical',
#  'tell',
#  'thrill',
#  'til',
#  'till',
#  'total',
#  'towel',
#  'troll',
#  'twoel',
#  'unreal',
#  'until',
#  'unusual',
#  'url',
#  'use full',
#  'usual',
#  'vinyl',
#  'virginal',
#  'visual',
#  'wall',
#  'weasel',
#  'wel',
#  'well',
#  'welll',
#  'wheel',
#  'will',
#  'withdrawal',
#  'withdrawl',
#  'wonderful',
#  'worl',
#  'yall',
#  'yell',
#  'yoll']

# %%
len(sorted(w for w in set(text5) if w.endswith('l')))
# Out:
# 203

# %% [markdown]
# ***Method 2:*** I am running it for all texts without considering the cases now.

# %%
sorted(set(w.lower() for w in text5 if w.endswith('l')))
# Out:
# ["'ll",
#  'al',
#  'alcohol',
#  'all',
#  'anal',
#  'angel',
#  'animal',
#  'anygirl',
#  'april',
#  'asl',
#  'astral',
#  'atl',
#  'bacl',
#  'bagel',
#  'ball',
#  'barrel',
#  'bbl',
#  'beautiful',
#  'bell',
#  'betrayal',
#  'bisexual',
#  'bowl',
#  'bull',
#  'cal',
#  'call',
#  'camel',
#  'careful',
#  'cell',
#  'channel',
#  'coastal',
#  'control',
#  'controll',
#  'cool',
#  'coudl',
#  'ctrl',
#  'daniel',
#  'deal',
#  'denial',
#  'denzel',
#  'devil',
#  'distrustful',
#  'dl',
#  'doll',
#  'e-mail',
#  'el',
#  'email',
#  'equal',
#  'evil',
#  'fall',
#  'fantastical',
#  'feel',
#  'financial',
#  'fl',
#  'fongul',
#  'fool',
#  'football',
#  'full',
#  'gal',
#  'genital',
#  'girl',
#  'grrl',
#  'gurrrrl',
#  'hail',
#  'hall',
#  'heal',
#  'hel',
#  'hell',
#  'helpful',
#  'hill',
#  'homosexual',
#  'howl',
#  'il',
#  'ill',
#  'individual',
#  'irl',
#  'jail',
#  'kewl',
#  'kill',
#  'kool',
#  'l',
#  'label',
#  'lawl',
#  'level',
#  'lil',
#  'll',
#  'local',
#  'lol',
#  'lolol',
#  'lolololll',
#  'lool',
#  'lysol',
#  'magical',
#  'maniacal',
#  'metal',
#  'moral',
#  'national',
#  'natural',
#  'novel',
#  'oatmeal',
#  'oatmel',
#  'occasional',
#  'official',
#  'oil',
#  'ol',
#  'original',
#  'painful',
#  'pal',
#  'partial',
#  'paul',
#  'paxil',
#  'paypal',
#  'pearl',
#  'peel',
#  'personal',
#  'phil',
#  'physical',
#  'pmsl',
#  'political',
#  'poll',
#  'pool',
#  'ppl',
#  'ppolitical',
#  'pull',
#  'quarrel',
#  'rascal',
#  'real',
#  'recall',
#  'refill',
#  'reschedual',
#  'rofl',
#  'roll',
#  'school',
#  'scroll',
#  'sell',
#  'sexual',
#  'shall',
#  'shell',
#  'shopgirl',
#  'small',
#  'smell',
#  'soul',
#  'special',
#  'spell',
#  'steal',
#  'steel',
#  'still',
#  'tail',
#  'tall',
#  'technical',
#  'tell',
#  'thrill',
#  'til',
#  'till',
#  'total',
#  'towel',
#  'troll',
#  'twoel',
#  'unreal',
#  'until',
#  'unusual',
#  'url',
#  'use full',
#  'usual',
#  'vinyl',
#  'virginal',
#  'visual',
#  'vvil',
#  'wall',
#  'weasel',
#  'wel',
#  'well',
#  'welll',
#  'wheel',
#  'will',
#  'withdrawal',
#  'withdrawl',
#  'wonderful',
#  'worl',
#  'yall',
#  'yell',
#  'yoll']

# %%
len(sorted(set((w.lower() for w in text5 if w.endswith('l')))))
# Out:
# 181

# %% [markdown]
# **Explanation:** We run a for loop on text5 for unique words which endswith the letter "l" and then sort them. The default order is ascending order. I also checked for how many such words are there and I found a total of 203 such words with taking in account the cases and 181 without cases.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 1.3 What is the difference between the following two lines of codes? Which one will give a larger value? Will this be the case for other texts?
# 1. sorted(set(w.lower() for w in text2))
# 2. sorted(w.lower() for w in set(text2))

# %% [markdown]
# **Explanation:** First let's understand what does set method do? It basically returns only the unique values. For example:
# I have a list as a = [1,2,3,3,4,4,4,4,5]. If I run set(a) then it will give me -> (1,2,3,4,5)
#
# In the first case we are looking for all the unique words which have been converted into lower case from text2.
# In the second case we are converting into lower case all the unique words in text2.
#
# The first one will have less because it first converts and then look for uniqueness while the second one first look for uniqueness and will include some words which are same but have different capitalizations and then converting them into lower case will lead to more records. Let's check the lengths for each code and see if our assumption is correct.

# %%
len(sorted(set(w.lower() for w in text2)))
# Out:
# 6403

# %%
len(sorted(w.lower() for w in set(text2)))
# Out:
# 6833

# %% [markdown]
# As assummed earlier we ran the code and included it inside the len() and found that second one give a larger value. The same thing will hold for any other text unless we see a special case where all words are in lower case such that the unique values with or without lower() method remains same.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 1.4 Find all the Twelve-letter words in the Chat Corpus (text2). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %% [markdown]
# There is a confusion to whether run it for chat corpus which is text 5 or text 2? So I run it for both

# %% [markdown]
# ***For Text 5: Chat Corpus***

# %%
sorted(set([w for w in text5 if w.isalpha() and len(w) == 12]))
# Out:
# ['Bloooooooood',
#  'Christianity',
#  'Connecticutt',
#  'Considerably',
#  'Constitution',
#  'Fergalicious',
#  'alternatives',
#  'bachelorette',
#  'butterscotch',
#  'catastrophic',
#  'christianity',
#  'constituents',
#  'construction',
#  'conversation',
#  'denomination',
#  'descriminate',
#  'disappointed',
#  'entertaining',
#  'freeeezinggg',
#  'hahahahahaha',
#  'heartbreaker',
#  'heyyyyyyyyyy',
#  'hhaaaaatttee',
#  'hugsssssssss',
#  'ihavehotnips',
#  'interruption',
#  'masturbating',
#  'multitasking',
#  'necromancers',
#  'neighborhood',
#  'oooooooooooo',
#  'outrageously',
#  'passionately',
#  'periodically',
#  'psychologist',
#  'registration',
#  'slkfjsldkfjs',
#  'subscription',
#  'sweeeeeeeeet',
#  'thanksgiving',
#  'tooooooooooo',
#  'yummylicious']

# %%
len(sorted(set([w for w in text5 if w.isalpha() and len(w) == 12])))
# Out:
# 42

# %%
chat_corpus = sorted([w for w in text5 if w.isalpha() and len(w) == 12])
FreqDist(chat_corpus).most_common()
# Out:
# [('conversation', 5),
#  ('construction', 3),
#  ('entertaining', 3),
#  ('multitasking', 2),
#  ('Bloooooooood', 1),
#  ('Christianity', 1),
#  ('Connecticutt', 1),
#  ('Considerably', 1),
#  ('Constitution', 1),
#  ('Fergalicious', 1),
#  ('alternatives', 1),
#  ('bachelorette', 1),
#  ('butterscotch', 1),
#  ('catastrophic', 1),
#  ('christianity', 1),
#  ('constituents', 1),
#  ('denomination', 1),
#  ('descriminate', 1),
#  ('disappointed', 1),
#  ('freeeezinggg', 1),
#  ('hahahahahaha', 1),
#  ('heartbreaker', 1),
#  ('heyyyyyyyyyy', 1),
#  ('hhaaaaatttee', 1),
#  ('hugsssssssss', 1),
#  ('ihavehotnips', 1),
#  ('interruption', 1),
#  ('masturbating', 1),
#  ('necromancers', 1),
#  ('neighborhood', 1),
#  ('oooooooooooo', 1),
#  ('outrageously', 1),
#  ('passionately', 1),
#  ('periodically', 1),
#  ('psychologist', 1),
#  ('registration', 1),
#  ('slkfjsldkfjs', 1),
#  ('subscription', 1),
#  ('sweeeeeeeeet', 1),
#  ('thanksgiving', 1),
#  ('tooooooooooo', 1),
#  ('yummylicious', 1)]

# %%
df = FreqDist(text5)
words  = sorted([w for w in text5 if w.isalpha() and len(w) == 12])
for i in [w for w in df]:
    if i not in words:
        df.pop(i)
print(df)
df.plot()
# Out:
# <FreqDist with 42 samples and 51 outcomes>

# %% [markdown]
# ***For Text 5: Sense and Sensibility by Jane Austen 1811***

# %%
[w for w in text2 if w.isalpha() and len(w) == 12]
# Out:
# ['acquaintance',
#  'cheerfulness',
#  'articulation',
#  'economically',
#  'considerable',
#  'considerable',
#  'successively',
#  'affectionate',
#  'wretchedness',
#  'cheerfulness',
#  'relationship',
#  'expectations',
#  'disagreeable',
#  'independence',
#  'inconvenient',
#  'occasionally',
#  'unreasonable',
#  'housekeeping',
#  'irresistible',
#  'remembrances',
#  'satisfaction',
#  'acquaintance',
#  'circumstance',
#  'circumstance',
#  'acquaintance',
#  'uninfluenced',
#  'acknowledged',
#  'affectionate',
#  'wretchedness',
#  'conversation',
#  'comprehended',
#  'affectionate',
#  'affectionate',
#  'intelligence',
#  'impenetrable',
#  'indifference',
#  'circumstance',
#  'performances',
#  'propensities',
#  'inclinations',
#  'dissatisfied',
#  'commendation',
#  'conversation',
#  'propensities',
#  'affectionate',
#  'acquaintance',
#  'imperfection',
#  'difficulties',
#  'indifference',
#  'expressively',
#  'expectations',
#  'insinuations',
#  'particularly',
#  'deliberation',
#  'acquaintance',
#  'acquiescence',
#  'satisfaction',
#  'conversation',
#  'undoubtingly',
#  'satisfaction',
#  'satisfaction',
#  'housekeeping',
#  'cheerfulness',
#  'honeysuckles',
#  'recollection',
#  'recommending',
#  'improvements',
#  'improvements',
#  'satisfaction',
#  'perseverance',
#  'satisfaction',
#  'Conversation',
#  'deficiencies',
#  'arrangements',
#  'satisfaction',
#  'friendliness',
#  'satisfaction',
#  'satisfaction',
#  'particularly',
#  'particularly',
#  'conversation',
#  'acquaintance',
#  'insinuations',
#  'impertinence',
#  'apprehensive',
#  'recollecting',
#  'conversation',
#  'affectionate',
#  'dissatisfied',
#  'independence',
#  'gracefulness',
#  'particularly',
#  'circumstance',
#  'acquaintance',
#  'intelligence',
#  'acquaintance',
#  'particularly',
#  'construction',
#  'transparency',
#  'passionately',
#  'acquaintance',
#  'acquaintance',
#  'conversation',
#  'acquaintance',
#  'affectionate',
#  'considerable',
#  'congratulate',
#  'satisfaction',
#  'indifference',
#  'undiscerning',
#  'observations',
#  'observations',
#  'commendation',
#  'endeavouring',
#  'unanswerable',
#  'satisfaction',
#  'accomplished',
#  'acquaintance',
#  'excellencies',
#  'illustration',
#  'satisfaction',
#  'conversation',
#  'acquaintance',
#  'conversation',
#  'acquaintance',
#  'indifference',
#  'disappointed',
#  'acquaintance',
#  'conversation',
#  'disappointed',
#  'perverseness',
#  'recollection',
#  'communicated',
#  'insufficient',
#  'representing',
#  'observations',
#  'communicated',
#  'circumstance',
#  'satisfactory',
#  'interruption',
#  'particularly',
#  'particularly',
#  'conveniently',
#  'lamentations',
#  'disappointed',
#  'consultation',
#  'considerable',
#  'acquaintance',
#  'circumstance',
#  'pleasantness',
#  'commendation',
#  'particularly',
#  'interruption',
#  'acquaintance',
#  'intermission',
#  'circumstance',
#  'incompatible',
#  'affectionate',
#  'improvements',
#  'disadvantage',
#  'expressively',
#  'satisfaction',
#  'acquaintance',
#  'handkerchief',
#  'exhilaration',
#  'cheerfulness',
#  'backwardness',
#  'affectionate',
#  'satisfactory',
#  'satisfactory',
#  'inadvertence',
#  'unanswerable',
#  'affectionate',
#  'circumstance',
#  'indifference',
#  'carelessness',
#  'difficulties',
#  'disadvantage',
#  'prosperously',
#  'recollection',
#  'explanations',
#  'overstrained',
#  'accidentally',
#  'continuation',
#  'particularly',
#  'sufficiently',
#  'transporting',
#  'conveniences',
#  'satisfaction',
#  'satisfaction',
#  'improvements',
#  'difficulties',
#  'acquaintance',
#  'expressively',
#  'satisfaction',
#  'reservedness',
#  'contradicted',
#  'particularly',
#  'promontories',
#  'indifference',
#  'thoughtfully',
#  'henceforward',
#  'particularly',
#  'acquaintance',
#  'instructions',
#  'acquaintance',
#  'Disappointed',
#  'independence',
#  'difficulties',
#  'independence',
#  'advantageous',
#  'independence',
#  'communicated',
#  'conversation',
#  'recollection',
#  'astonishment',
#  'conversation',
#  'disappointed',
#  'acquaintance',
#  'contradicted',
#  'indifference',
#  'unaffectedly',
#  'contemptuous',
#  'establishing',
#  'disappointed',
#  'acquaintance',
#  'confirmation',
#  'intelligence',
#  'commendation',
#  'acquaintance',
#  'satisfaction',
#  'enthusiastic',
#  'commendation',
#  'acquaintance',
#  'indifference',
#  'introduction',
#  'acknowledged',
#  'considerable',
#  'particularly',
#  'handkerchief',
#  'successfully',
#  'intermission',
#  'commendation',
#  'distractedly',
#  'conversation',
#  'accomplished',
#  'particularly',
#  'significancy',
#  'disadvantage',
#  'impertinence',
#  'particularly',
#  'conversation',
#  'acquaintance',
#  'satisfaction',
#  'conversation',
#  'astonishment',
#  'Astonishment',
#  'astonishment',
#  'acquaintance',
#  'considerable',
#  'acquaintance',
#  'particularly',
#  'acquaintance',
#  'handkerchief',
#  'circumstance',
#  'particularly',
#  'accidentally',
#  'conversation',
#  'contradicted',
#  'acquaintance',
#  'indisputable',
#  'tranquillity',
#  'difficulties',
#  'difficulties',
#  'expectations',
#  'condemnation',
#  'conversation',
#  'cheerfulness',
#  'conversation',
#  'particularly',
#  'acquaintance',
#  'intelligence',
#  'endeavouring',
#  'conversation',
#  'consequences',
#  'sufficiently',
#  'conversation',
#  'disappointed',
#  'cheerfulness',
#  'endeavouring',
#  'difficulties',
#  'unpardonable',
#  'particularly',
#  'difficulties',
#  'confidential',
#  'particularly',
#  'unexpectedly',
#  'indifference',
#  'inclinations',
#  'indifference',
#  'cautiousness',
#  'affectionate',
#  'cheerfulness',
#  'indifference',
#  'recollecting',
#  'unreasonable',
#  'acquaintance',
#  'indifference',
#  'astonishment',
#  'intelligence',
#  'counteracted',
#  'dissatisfied',
#  'perturbation',
#  'acquaintance',
#  'intelligence',
#  'observations',
#  'unfavourable',
#  'satisfaction',
#  'complaisance',
#  'mysteriously',
#  'satisfactory',
#  'satisfaction',
#  'disappointed',
#  'neighbouring',
#  'disappointed',
#  'particularly',
#  'astonishment',
#  'recollection',
#  'cheerfulness',
#  'commissioned',
#  'acquaintance',
#  'dissatisfied',
#  'disappointed',
#  'interference',
#  'acquaintance',
#  'recollection',
#  'watchfulness',
#  'acquaintance',
#  'dissatisfied',
#  'acquaintance',
#  'arrangements',
#  'introduction',
#  'satisfaction',
#  'conversation',
#  'satisfaction',
#  'congratulate',
#  'accidentally',
#  'endeavouring',
#  'acknowledged',
#  'conversation',
#  'insufferably',
#  'conversation',
#  'explanations',
#  'exclamations',
#  'wretchedness',
#  'unprincipled',
#  'circumstance',
#  'irritability',
#  'endeavouring',
#  'considerable',
#  'handkerchief',
#  'acquaintance',
#  'acknowledged',
#  'astonishment',
#  'irremediable',
#  'unprincipled',
#  'unreasonably',
#  'astonishment',
#  'contributing',
#  'astonishment',
#  'endeavouring',
#  'condemnation',
#  'supplication',
#  'acquaintance',
#  'thoughtfully',
#  'unpardonable',
#  'premeditated',
#  'acquaintance',
#  'acquaintance',
#  'conversation',
#  'conveniences',
#  'perverseness',
#  'disappointed',
#  'hesitatingly',
#  'unfathomable',
#  'preparations',
#  'astonishment',
#  'affectionate',
#  'circumstance',
#  'outstretched',
#  'satisfactory',
#  'recollection',
#  'conversation',
#  'conversation',
#  'recollection',
#  'guardianship',
#  'recollection',
#  'extravagance',
#  'acquaintance',
#  'dishonorable',
#  'unworthiness',
#  'Recollecting',
#  'conversation',
#  'satisfaction',
#  'communicated',
#  'acquaintance',
#  'wretchedness',
#  'acquaintance',
#  'recollecting',
#  'humiliations',
#  'intelligence',
#  'overpowering',
#  'disappointed',
#  'conversation',
#  'impertinence',
#  'indifference',
#  'satisfaction',
#  'friendliness',
#  'satisfaction',
#  'congratulate',
#  'enthusiastic',
#  'satisfaction',
#  'Recollecting',
#  'particularly',
#  'considerable',
#  'congratulate',
#  'acquaintance',
#  'advantageous',
#  'particularly',
#  'relinquished',
#  'acquaintance',
#  'prepossessed',
#  'satisfactory',
#  'expectations',
#  'intelligence',
#  'prodigiously',
#  'acquaintance',
#  'introduction',
#  'indifference',
#  'particularly',
#  'difficulties',
#  'endeavouring',
#  'recollection',
#  'proportioned',
#  'graciousness',
#  'particularly',
#  'graciousness',
#  'improvements',
#  'conversation',
#  'considerable',
#  'particularly',
#  'grandmothers',
#  'performances',
#  'particularly',
#  'delightfully',
#  'affectionate',
#  'difficulties',
#  'affectionate',
#  'constitution',
#  'difficulties',
#  'satisfaction',
#  'difficulties',
#  'circumstance',
#  'recollection',
#  'indifference',
#  'contribution',
#  'disagreeable',
#  'particularly',
#  'commendation',
#  'commendation',
#  'particularly',
#  'contradicted',
#  'consequences',
#  'satisfactory',
#  'conciliation',
#  'indifference',
#  'acquaintance',
#  'circumstance',
#  'imaginations',
#  'indifference',
#  'mechanically',
#  'impertinence',
#  'impertinence',
#  'acquaintance',
#  'comprehended',
#  'unrestrained',
#  'conversation',
#  'irremediable',
#  'satisfaction',
#  'refreshments',
#  'communicated',
#  'acknowledged',
#  'expectations',
#  'acquaintance',
#  'strengthened',
#  'observations',
#  'impartiality',
#  'endeavouring',
#  'astonishment',
#  'endeavouring',
#  'circumstance',
#  'constitution',
#  'affectionate',
#  'apprehension',
#  'recollection',
#  'dissatisfied',
#  'acquaintance',
#  'conversation',
#  'satisfaction',
#  'triumphantly',
#  'interrupting',
#  'conversation',
#  'intelligence',
#  'persecutions',
#  'respectfully',
#  'satisfaction',
#  'difficulties',
#  'confirmation',
#  'astonishment',
#  'presentation',
#  'conversation',
#  'disappointed',
#  'deliberating',
#  'astonishment',
#  'particularly',
#  'congratulate',
#  'considerable',
#  'astonishment',
#  'solicitation',
#  'benefactress',
#  'acknowledged',
#  'acquaintance',
#  'particularly',
#  'anticipation',
#  'considerable',
#  'satisfaction',
#  'backwardness',
#  'accidentally',
#  'relationship',
#  'presentation',
#  'recollection',
#  'presentation',
#  'contradicted',
#  'impoverished',
#  'satisfaction',
#  'circumstance',
#  'affectionate',
#  'circumstance',
#  'recollecting',
#  'acquaintance',
#  'unfavourable',
#  'immoderately',
#  'intelligence',
#  'considerably',
#  'acquaintance',
#  'disapproving',
#  'affectionate',
#  'extinguished',
#  'satisfaction',
#  'guardianship',
#  'interspersed',
#  'lamentations',
#  'disappointed',
#  'recollection',
#  'conversation',
#  'occasionally',
#  'intelligence',
#  'deficiencies',
#  'disappointed',
#  'endeavouring',
#  'arrangements',
#  'cheerfulness',
#  'auspiciously',
#  'satisfaction',
#  'considerable',
#  'inarticulate',
#  'difficulties',
#  'difficulties',
#  'incoherently',
#  'communicated',
#  'particularly',
#  'disappointed',
#  'conversation',
#  'tranquillity',
#  'cheerfulness',
#  'satisfaction',
#  'intermission',
#  'particularly',
#  'supplication',
#  'recollection',
#  'acquiescence',
#  'astonishment',
#  'intelligible',
#  'intelligence',
#  'unpardonable',
#  'intoxication',
#  'recollection',
#  'acquaintance',
#  'contemptuous',
#  'contemptible',
#  'circumstance',
#  'circumstance',
#  'indifference',
#  'indifference',
#  'discontented',
#  'deliberating',
#  'insufficient',
#  'Thunderbolts',
#  'conversation',
#  'acquaintance',
#  'watchfulness',
#  'acquaintance',
#  'affectionate',
#  'breakfasting',
#  'wretchedness',
#  'unprincipled',
#  'carelessness',
#  'ingratiating',
#  'undiscerning',
#  'independence',
#  'affectionate',
#  'Extravagance',
#  'extravagance',
#  'acknowledged',
#  'affectionate',
#  'apprehension',
#  'conversation',
#  'intelligence',
#  'cheerfulness',
#  'undesignedly',
#  'irresistible',
#  'considerable',
#  'acknowledged',
#  'strengthened',
#  'particularly',
#  'cheerfulness',
#  'recollection',
#  'cheerfulness',
#  'strengthened',
#  'anticipating',
#  'tranquillity',
#  'hesitatingly',
#  'recollection',
#  'acquaintance',
#  'acquaintance',
#  'complaisance',
#  'conjecturing',
#  'conversation',
#  'acknowledged',
#  'inexperience',
#  'difficulties',
#  'difficulties',
#  'intelligence',
#  'intelligence',
#  'intelligence',
#  'acknowledged',
#  'intelligence',
#  'consequently',
#  'astonishment',
#  'affectionate',
#  'astonishment',
#  'experiencing',
#  'particularly',
#  'entanglement',
#  'cheerfulness',
#  'acquaintance',
#  'satisfaction',
#  'unrestrained',
#  'conversation',
#  'familiarized',
#  'tranquillity',
#  'accidentally',
#  'acquaintance',
#  'affectionate',
#  'relationship',
#  'independence',
#  'disinherited',
#  'acquaintance',
#  'advantageous',
#  'ungraciously',
#  'satisfaction',
#  'consequently',
#  'acquaintance',
#  'unpardonable',
#  'acknowledged',
#  'astonishment',
#  'improvements',
#  'annihilation',
#  'annihilation',
#  'circumstance',
#  'constitution',
#  'apprehensive',
#  'considerable',
#  'improvements',
#  'experiencing',
#  'dilatoriness',
#  'disappointed',
#  'acquaintance',
#  'conversation',
#  'comprehended',
#  'transgressed',
#  'perseverance',
#  'condemnation',
#  'graciousness',
#  'acknowledged',
#  'cheerfulness',
#  'irresistible',
#  'cheerfulness',
#  'inconsolable',
#  'considerable',
#  'disagreement']

# %%
len(sorted(set([w for w in text2 if len(w) == 12])))
# Out:
# 205

# %%
text2_words = [w for w in text2 if len(w) == 12]

# %%
fdist_text2 = FreqDist(text2_words)

# %%
fdist_text2
fdist_text2.most_common()
# Out:
# [('acquaintance', 64),
#  ('conversation', 39),
#  ('satisfaction', 37),
#  ('particularly', 34),
#  ('affectionate', 22),
#  ('circumstance', 19),
#  ('indifference', 19),
#  ('recollection', 18),
#  ('intelligence', 17),
#  ('difficulties', 17),
#  ('astonishment', 17),
#  ('cheerfulness', 16),
#  ('disappointed', 16),
#  ('considerable', 15),
#  ('acknowledged', 12),
#  ('endeavouring', 10),
#  ('commendation', 8),
#  ('independence', 7),
#  ('improvements', 7),
#  ('satisfactory', 7),
#  ('dissatisfied', 6),
#  ('communicated', 6),
#  ('wretchedness', 5),
#  ('expectations', 5),
#  ('impertinence', 5),
#  ('congratulate', 5),
#  ('observations', 5),
#  ('accidentally', 5),
#  ('contradicted', 5),
#  ('recollecting', 4),
#  ('handkerchief', 4),
#  ('tranquillity', 4),
#  ('unpardonable', 4),
#  ('relationship', 3),
#  ('irresistible', 3),
#  ('comprehended', 3),
#  ('expressively', 3),
#  ('arrangements', 3),
#  ('intermission', 3),
#  ('disadvantage', 3),
#  ('advantageous', 3),
#  ('introduction', 3),
#  ('condemnation', 3),
#  ('unprincipled', 3),
#  ('graciousness', 3),
#  ('constitution', 3),
#  ('strengthened', 3),
#  ('presentation', 3),
#  ('disagreeable', 2),
#  ('occasionally', 2),
#  ('unreasonable', 2),
#  ('housekeeping', 2),
#  ('performances', 2),
#  ('propensities', 2),
#  ('inclinations', 2),
#  ('insinuations', 2),
#  ('acquiescence', 2),
#  ('perseverance', 2),
#  ('deficiencies', 2),
#  ('friendliness', 2),
#  ('apprehensive', 2),
#  ('undiscerning', 2),
#  ('unanswerable', 2),
#  ('accomplished', 2),
#  ('perverseness', 2),
#  ('insufficient', 2),
#  ('interruption', 2),
#  ('lamentations', 2),
#  ('backwardness', 2),
#  ('carelessness', 2),
#  ('explanations', 2),
#  ('sufficiently', 2),
#  ('conveniences', 2),
#  ('thoughtfully', 2),
#  ('contemptuous', 2),
#  ('confirmation', 2),
#  ('enthusiastic', 2),
#  ('consequences', 2),
#  ('unfavourable', 2),
#  ('complaisance', 2),
#  ('watchfulness', 2),
#  ('irremediable', 2),
#  ('supplication', 2),
#  ('hesitatingly', 2),
#  ('guardianship', 2),
#  ('extravagance', 2),
#  ('Recollecting', 2),
#  ('unrestrained', 2),
#  ('apprehension', 2),
#  ('deliberating', 2),
#  ('consequently', 2),
#  ('experiencing', 2),
#  ('annihilation', 2),
#  ('articulation', 1),
#  ('economically', 1),
#  ('successively', 1),
#  ('inconvenient', 1),
#  ('remembrances', 1),
#  ('uninfluenced', 1),
#  ('impenetrable', 1),
#  ('imperfection', 1),
#  ('deliberation', 1),
#  ('undoubtingly', 1),
#  ('honeysuckles', 1),
#  ('recommending', 1),
#  ('Conversation', 1),
#  ('gracefulness', 1),
#  ('construction', 1),
#  ('transparency', 1),
#  ('passionately', 1),
#  ('excellencies', 1),
#  ('illustration', 1),
#  ('representing', 1),
#  ('conveniently', 1),
#  ('consultation', 1),
#  ('pleasantness', 1),
#  ('incompatible', 1),
#  ('exhilaration', 1),
#  ('inadvertence', 1),
#  ('prosperously', 1),
#  ('overstrained', 1),
#  ('continuation', 1),
#  ('transporting', 1),
#  ('reservedness', 1),
#  ('promontories', 1),
#  ('henceforward', 1),
#  ('instructions', 1),
#  ('Disappointed', 1),
#  ('unaffectedly', 1),
#  ('establishing', 1),
#  ('successfully', 1),
#  ('distractedly', 1),
#  ('significancy', 1),
#  ('Astonishment', 1),
#  ('indisputable', 1),
#  ('confidential', 1),
#  ('unexpectedly', 1),
#  ('cautiousness', 1),
#  ('counteracted', 1),
#  ('perturbation', 1),
#  ('mysteriously', 1),
#  ('neighbouring', 1),
#  ('commissioned', 1),
#  ('interference', 1),
#  ('insufferably', 1),
#  ('exclamations', 1),
#  ('irritability', 1),
#  ('unreasonably', 1),
#  ('contributing', 1),
#  ('premeditated', 1),
#  ('unfathomable', 1),
#  ('preparations', 1),
#  ('outstretched', 1),
#  ('dishonorable', 1),
#  ('unworthiness', 1),
#  ('humiliations', 1),
#  ('overpowering', 1),
#  ('relinquished', 1),
#  ('prepossessed', 1),
#  ('prodigiously', 1),
#  ('proportioned', 1),
#  ('grandmothers', 1),
#  ('delightfully', 1),
#  ('contribution', 1),
#  ('conciliation', 1),
#  ('imaginations', 1),
#  ('mechanically', 1),
#  ('refreshments', 1),
#  ('impartiality', 1),
#  ('triumphantly', 1),
#  ('interrupting', 1),
#  ('persecutions', 1),
#  ('respectfully', 1),
#  ('solicitation', 1),
#  ('benefactress', 1),
#  ('anticipation', 1),
#  ('impoverished', 1),
#  ('immoderately', 1),
#  ('considerably', 1),
#  ('disapproving', 1),
#  ('extinguished', 1),
#  ('interspersed', 1),
#  ('auspiciously', 1),
#  ('inarticulate', 1),
#  ('incoherently', 1),
#  ('intelligible', 1),
#  ('intoxication', 1),
#  ('contemptible', 1),
#  ('discontented', 1),
#  ('Thunderbolts', 1),
#  ('breakfasting', 1),
#  ('ingratiating', 1),
#  ('Extravagance', 1),
#  ('undesignedly', 1),
#  ('anticipating', 1),
#  ('conjecturing', 1),
#  ('inexperience', 1),
#  ('entanglement', 1),
#  ('familiarized', 1),
#  ('disinherited', 1),
#  ('ungraciously', 1),
#  ('dilatoriness', 1),
#  ('transgressed', 1),
#  ('inconsolable', 1),
#  ('disagreement', 1)]

# %% [markdown]
# **Explanation:** I run a loop to find all the words which are alphabets only and have a length of 12 and pass that into a set() method to get unique records. Then I sorted them and print it.
#
# Furthermore, I save the above result to 'words' variable and then using the frequency distribution function I plot the 12 letter words in the sequence of their total counts in descending order.

# %%
df = FreqDist(text2)
words  = sorted([w for w in text2 if w.isalpha() and len(w) == 12])
for i in [w for w in df]:
    if i not in words:
        df.pop(i)
print(df)
df.plot()
# Out:
# <FreqDist with 205 samples and 711 outcomes>

# %% [markdown]
# ----

# %% [markdown]
# #### Question 1.5 Review the discussion of looping with conditions in Section 4 in Chapter 1. Use a combination of for and if statements to loop over the tokens of text2 and print all the distinct punctuation, one per line.

# %% [markdown]
# **Method 1:** I use the punctuation class from string package to find all the punctuations in the text 2

# %%
from string import punctuation as punc

# %%
set(w for w in text2 if w in punc)
# Out:
# {'!',
#  '!"',
#  '"',
#  '&',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',-',
#  '-',
#  '.',
#  ':',
#  ';',
#  '>',
#  '?',
#  '[',
#  ']'}

# %%
len(set(w for w in text2 if w in punc))
# Out:
# 17

# %% [markdown]
# **Method 2:** I use to find all varities of punctuation by selecting anything that is not alpha numeric.

# %%
text2_punc = [w for w in text2 if not w.isalnum()]

# %%
text2_punc
# Out:
# ['[',
#  ']',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  "'",
#  '.',
#  '.',
#  '.',
#  '.',
#  ',',
#  ',',
#  ',',
#  ';',
#  '.',
#  ',',
#  '.',
#  ':',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  ';',
#  ',',
#  "'",
#  ',',
#  '.',
#  ',',
#  ';',
#  "'",
#  ',',
#  '-',
#  '.',
#  ':',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';--',
#  '.',
#  '.',
#  ';--',
#  ',',
#  "'",
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  '-',
#  '.',
#  '.',
#  "'",
#  ',',
#  ',',
#  ';',
#  ';',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  ';',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ',',
#  '-',
#  '-',
#  '.',
#  '.',
#  ';',
#  ',',
#  '.',
#  ',',
#  '.',
#  '.',
#  '-',
#  ',',
#  '-',
#  ':',
#  ',',
#  ',',
#  ';',
#  '.',
#  ',',
#  ':--',
#  ';',
#  ',',
#  '.',
#  '.',
#  ';--',
#  '-',
#  '.',
#  ',',
#  '-',
#  '.',
#  '.',
#  '-',
#  ',',
#  ',',
#  "'",
#  ',',
#  ',',
#  '.--',
#  '"',
#  ',',
#  ':',
#  '!',
#  '.',
#  '!',
#  '."--',
#  ',',
#  ',',
#  '.',
#  "'",
#  ',',
#  '.',
#  ',',
#  '-',
#  '-',
#  ',',
#  '.',
#  ';',
#  "'",
#  "'",
#  ';',
#  ',',
#  '.',
#  "'",
#  ',',
#  ',',
#  ';--',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  "'",
#  ';',
#  ',',
#  ',',
#  '.',
#  '.',
#  ',',
#  '-',
#  '-',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  ';--',
#  ',',
#  ';',
#  ':',
#  ';',
#  '.',
#  "'",
#  ',',
#  ',',
#  "'",
#  '.',
#  ';',
#  ':',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ':',
#  '.',
#  '.',
#  ',',
#  ',',
#  "'",
#  ';',
#  '.',
#  '.',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  '-',
#  '-',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  ',',
#  '-',
#  ',',
#  '-',
#  ';',
#  "'",
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  ';',
#  '-',
#  '-',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  ',',
#  ',',
#  '?',
#  ',',
#  ',',
#  ',',
#  '.',
#  ';',
#  ',',
#  ',',
#  '?',
#  '"',
#  "'",
#  ',"',
#  ',',
#  '"',
#  '."',
#  '"',
#  ',',
#  ';',
#  '-',
#  '.',
#  ',',
#  '."',
#  '"',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  '.',
#  ',',
#  ';',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  '."',
#  '"',
#  ',',
#  ',',
#  ';',
#  '.',
#  ',"',
#  ',',
#  '"',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ',',
#  '--"',
#  '"',
#  ',',
#  ',"',
#  ',',
#  ',',
#  '"',
#  '.',
#  '.',
#  ',',
#  ',',
#  '."',
#  '"',
#  '."',
#  '"',
#  ',',
#  ',',
#  ',',
#  '.--',
#  '!"',
#  '"',
#  '!',
#  '!',
#  ',',
#  '!',
#  '--',
#  '!--',
#  '!"',
#  '"',
#  ',"',
#  '.',
#  '"',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ':',
#  ',',
#  '."',
#  '"',
#  ',"',
#  ',',
#  '"',
#  ':',
#  ',',
#  '."',
#  '"',
#  '--',
#  '-',
#  '.',
#  ',',
#  ',',
#  "'",
#  '--',
#  '."',
#  '"',
#  ';',
#  ',',
#  ',',
#  '.',
#  '.',
#  ',',
#  ',',
#  ',',
#  '."',
#  '"',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '--',
#  '.--',
#  '.',
#  '."',
#  ',',
#  ',',
#  '.',
#  '"',
#  ',"',
#  ',',
#  '"',
#  '.',
#  ',',
#  ',',
#  '.',
#  '."',
#  '"',
#  '!',
#  ';',
#  '."',
#  '"',
#  ';',
#  ',',
#  ';',
#  ',',
#  '.',
#  ';',
#  ',',
#  '.',
#  '.',
#  ';',
#  "'",
#  ',',
#  '.',
#  ';',
#  ';',
#  ',',
#  '.',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  "'",
#  ',',
#  '.',
#  ',',
#  '."',
#  '"',
#  ',"',
#  '.',
#  ',',
#  '"',
#  "'",
#  '.',
#  "'",
#  ',',
#  ',',
#  "'",
#  '.',
#  ',',
#  ',',
#  ':',
#  "'",
#  '."',
#  '"',
#  ';',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  '.',
#  ',',
#  '."',
#  '"',
#  ',',
#  ';',
#  ';',
#  ',',
#  ',',
#  '.',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '."',
#  '"',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  "'",
#  ';',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  '-',
#  '-',
#  ',',
#  ',',
#  '-',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  '-',
#  ',',
#  '?--',
#  '!',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  '!',
#  '!',
#  '!',
#  ';',
#  ',',
#  '.',
#  '."',
#  '"',
#  ',"',
#  '.',
#  ',',
#  '"',
#  '.',
#  '.',
#  ',',
#  '.',
#  '.',
#  '."',
#  '"',
#  ',"',
#  '.',
#  '.',
#  '"',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '."',
#  '"',
#  '.',
#  '!',
#  '."',
#  '"',
#  ';',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  '.',
#  ':',
#  ',',
#  ';',
#  ',',
#  '."',
#  '.',
#  ';',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  ';',
#  ';',
#  ',',
#  ',',
#  ',',
#  ';',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  ',',
#  '.',
#  ',',
#  "'",
#  ',',
#  '.',
#  "'",
#  ',',
#  ',',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '-',
#  '-',
#  ',',
#  ',',
#  "'",
#  ';',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  "'",
#  '.',
#  '.',
#  ',',
#  '-',
#  ',',
#  "'",
#  ',',
#  '.',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  '.',
#  ',',
#  ',',
#  '.',
#  "'",
#  ';',
#  "'",
#  ',',
#  '.',
#  '.',
#  ',',
#  '.',
#  ';',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  '--',
#  '--',
#  '.',
#  '.',
#  ',',
#  ',',
#  '.',
#  '.',
#  ';',
#  ',',
#  ',',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  "'",
#  ';',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  '-',
#  '.',
#  ',',
#  '.',
#  '.',
#  '"',
#  ',"',
#  ';',
#  '"',
#  '.',
#  '.',
#  '."',
#  '"',
#  ',"',
#  ',',
#  '"',
#  '."',
#  '"',
#  '!"',
#  '.',
#  '"',
#  '."',
#  '"',
#  '."',
#  '"',
#  '."',
#  '.',
#  '.',
#  ',',
#  '.',
#  ';',
#  ';',
#  ':',
#  ',',
#  "'",
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  '"',
#  ',',
#  '."',
#  ',',
#  '"',
#  ',',
#  '.',
#  ';',
#  '."',
#  '"',
#  '!',
#  ',',
#  '?"',
#  '"',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  "'",
#  '.',
#  ',',
#  ';',
#  "'",
#  '?"',
#  '"',
#  ',"',
#  ',',
#  '"',
#  '.',
#  ',',
#  '.',
#  '--',
#  '--',
#  '--',
#  ';',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  "'",
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  '.',
#  '.',
#  ';',
#  ',',
#  '.',
#  '!',
#  ',',
#  ',',
#  "'",
#  '!',
#  '.',
#  ',',
#  '.',
#  '.',
#  ',',
#  ',',
#  '!"--',
#  '"',
#  '.',
#  ';',
#  '."',
#  '"',
#  ',',
#  ',',
#  '!--',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  '!',
#  "'",
#  ',',
#  '."',
#  '"',
#  ',',
#  ',',
#  '.',
#  '.',
#  '?',
#  ',',
#  ',',
#  "'",
#  '!"',
#  '"',
#  ',',
#  ',"',
#  ',',
#  '"',
#  '."',
#  '"',
#  '!"',
#  ',',
#  '"',
#  '?',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ';',
#  ',',
#  '."',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '.',
#  '"',
#  ',',
#  ',"',
#  ',',
#  '"',
#  '.',
#  ',',
#  ',',
#  ',',
#  ',',
#  '."',
#  '.',
#  ',',
#  '.',
#  ':',
#  '"',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  '.',
#  '."',
#  '"',
#  ',"',
#  ',',
#  ',',
#  '"',
#  '.',
#  '."',
#  '.',
#  '"',
#  ',"',
#  ',',
#  '"',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  '.',
#  ',',
#  '.',
#  ',',
#  '.',
#  ',',
#  ';',
#  ',',
#  ',',
#  '-',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  '.',
#  ',',
#  ';',
#  ',',
#  ',',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  ';',
#  ',',
#  '.',
#  ',',
#  '?"',
#  '"',
#  ',',
#  ',',
#  '.',
#  ',',
#  ',',
#  '."',
#  ',',
#  ',',
#  '.',
#  '.',
#  ';',
#  "'",
#  '.',
#  ',',
#  '--',
#  ',',
#  ',',
#  '.',
#  '.',
#  '"',
#  ',"',
#  ',',
#  '"',
#  '--',
#  ',',
#  ...]

# %%
len(text2_punc)
# Out:
# 20789

# %% [markdown]
# **Explanation:** I call the punctuation method from string class to get all the punctions by running a for loop on text 2 with an if condition for punctuations and then pass this entire code inside set method for unique values. There are 17 different punctuations in text 2.

# %% [markdown]
# ----

# %% [markdown]
# # Chapter 2

# %% [markdown]
# #### Question 2.1 Use Gutenberg Corpus Module to explore 'shakespeare-caesar.txt'.
#
# - How many word tokens does this book have?
# - How many word types?
# - What is the lexical richness?

# %%
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
caesar = gutenberg.words('shakespeare-caesar.txt')

# %%
print("Number of word tokens = ", len(caesar))
print("Number of word types  = ", len(set(caesar)))
print("Lexical richness      = ", round(len(set(caesar))/len(caesar)*100,2), "%")
# Out:
# Number of word tokens =  25833
# Number of word types  =  3560
# Lexical richness      =  13.78 %

# %% [markdown]
# **Explanation:** I call len() method to get total word tokens and len() with set() method to get word types. When I take the ratio of these two, I get the lexical richness of our file.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 2.2 Explore the Section "Hobbies" in Brown Corpus. Count the number of wh words, such as what, when, where, who and why. Please make sure we are not double-counting words like “This” and “this”, which differ only in capitalization.

# %%
from nltk.corpus import brown

# %%
hobbies_text = brown.words(categories='hobbies')

# %%
sorted(set(wh.lower() for wh in hobbies_text if wh.lower().startswith('wh')))
# Out:
# ['whaddya',
#  'whaling',
#  'what',
#  "what's",
#  'whatever',
#  'wheel',
#  'wheeled',
#  'wheels',
#  'when',
#  'whenever',
#  'where',
#  'whereas',
#  'whereby',
#  'wherein',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whip',
#  'whipped',
#  'whippet',
#  'whips',
#  'whirlwind',
#  'whiskey',
#  'white',
#  'whitetail',
#  'who',
#  'whole',
#  'whole-house',
#  'wholesale',
#  'wholly',
#  'whom',
#  'whose',
#  'why']

# %%
len(sorted(set(wh.lower() for wh in hobbies_text if wh.lower().startswith('wh'))))
# Out:
# 34

# %%
hobbies_text_cw = sorted(wh.lower() for wh in hobbies_text if wh.lower().startswith('wh'))
sorted(FreqDist(hobbies_text_cw).most_common())
# Out:
# [('whaddya', 1),
#  ('whaling', 1),
#  ('what', 108),
#  ("what's", 1),
#  ('whatever', 6),
#  ('wheel', 4),
#  ('wheeled', 2),
#  ('wheels', 3),
#  ('when', 164),
#  ('whenever', 2),
#  ('where', 77),
#  ('whereas', 2),
#  ('whereby', 1),
#  ('wherein', 1),
#  ('wherever', 3),
#  ('whether', 14),
#  ('which', 253),
#  ('while', 38),
#  ('whip', 1),
#  ('whipped', 2),
#  ('whippet', 1),
#  ('whips', 1),
#  ('whirlwind', 1),
#  ('whiskey', 1),
#  ('white', 15),
#  ('whitetail', 2),
#  ('who', 104),
#  ('whole', 20),
#  ('whole-house', 1),
#  ('wholesale', 1),
#  ('wholly', 2),
#  ('whom', 2),
#  ('whose', 14),
#  ('why', 17)]

# %% [markdown]
# **Explanation:** Call the Brown Corpus and choose the 'hobbies' category. Use the FreqDist() method to call all the words in the text from the selected category. Ensure we have all the words converted to lower to avoid duplicates that may arise due to capitalization. Then run a loop for the words which starts with "wh". Use a for loop to run this array over the frequecny distribution method to get the unique counts for each of those "wh" words.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 2.3 Explore movie reviews corpus which contains 2k movie reviews with sentiment polarity classification (positive or negative reviews). Please find out the 20 most common words in the negative reviews and positive reviews. Please get rid of stop words, number and punctuations from reviews. Please make sure we are not double-counting words like “This” and “this”, which differ only in capitalization.
#
# Hint:
# - from nltk.corpus import movie_reviews
# - from nltk.corpus import stopwords

# %%
from nltk.corpus import movie_reviews
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
len(movie_reviews.words()) # Prints total number of words in 'movie_reviews'
# Out:
# 1583820

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
documents = []
 
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
 
print (len(documents))
# Out:
# 2000

# %%
len(movie_reviews.fileids("neg"))
# Out:
# 1000

# %%
len(movie_reviews.fileids("pos"))
# Out:
# 1000

# %%
text = movie_reviews.words()

# %% [markdown]
# ***Method 1:*** For both postive and negative words together

# %%
def most_freq_words(text):
    fdist = FreqDist(w.lower() for w in text if w.isalpha() and w.lower() not in stopwords.words('english'))
    return fdist.most_common(20)

most_freq_words(text)
# Out:
# [('film', 9517),
#  ('one', 5852),
#  ('movie', 5771),
#  ('like', 3690),
#  ('even', 2565),
#  ('good', 2411),
#  ('time', 2411),
#  ('story', 2169),
#  ('would', 2109),
#  ('much', 2049),
#  ('character', 2020),
#  ('also', 1967),
#  ('get', 1949),
#  ('two', 1911),
#  ('well', 1906),
#  ('characters', 1859),
#  ('first', 1836),
#  ('see', 1749),
#  ('way', 1693),
#  ('make', 1642)]

# %% [markdown]
# ***Method 2:*** For both postive and negative words separately

# %%
neg_w = []
for fileid in movie_reviews.fileids('neg'):
    check = movie_reviews.words(fileid)
    for w in check:
        if w.lower() not in stopwords and w.isalpha():
            neg_w.append(w.lower())
fdist_neg_w = FreqDist(neg_w)


pos_w = []
for fileid in movie_reviews.fileids('pos'):
    check = movie_reviews.words(fileid)
    for w in check:
        if w.lower() not in stopwords and w.isalpha():
            pos_w.append(w.lower())
fdist_pos_w = FreqDist(pos_w)

# %%
fdist_neg_w.most_common(20)
# Out:
# [('film', 4287),
#  ('movie', 3246),
#  ('one', 2800),
#  ('like', 1888),
#  ('even', 1386),
#  ('time', 1168),
#  ('good', 1163),
#  ('would', 1090),
#  ('get', 1052),
#  ('bad', 1034),
#  ('much', 1011),
#  ('character', 942),
#  ('story', 923),
#  ('plot', 917),
#  ('two', 912),
#  ('characters', 873),
#  ('make', 851),
#  ('first', 832),
#  ('could', 791),
#  ('see', 784)]

# %%
fdist_pos_w.most_common(20)
# Out:
# [('film', 5230),
#  ('one', 3052),
#  ('movie', 2525),
#  ('like', 1802),
#  ('good', 1248),
#  ('story', 1246),
#  ('time', 1243),
#  ('also', 1200),
#  ('even', 1179),
#  ('well', 1123),
#  ('character', 1078),
#  ('life', 1057),
#  ('much', 1038),
#  ('would', 1019),
#  ('first', 1004),
#  ('two', 999),
#  ('characters', 986),
#  ('see', 965),
#  ('way', 929),
#  ('get', 897)]

# %% [markdown]
# **Explanation:** We call the movie_reviews from ntlk corpus and then check for the categories and we found that there are exactly 1000 reviews for both negative and positive types.
#
# We then write a function that can find the frequency fo the top 20 words. The conditions we will needs inside the FreqDist() method is that the words must be lower case and are alphabets only which are not stopwords. The flow of which can be seen from the above code. Then use the most common method to pass a number as an argument which is basically the number of words we wish to run this fucntion for.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 2.4 Explore Names Corpus, which initial letters are more frequent for males vs. females? ((Hint: Plot of a Conditional Frequency Distribution will be useful for answering this question)

# %%
from nltk.corpus import names

# %%
cfd = nltk.ConditionalFreqDist(
             (fileid, name[0])
             for fileid in names.fileids()
             for name in names.words(fileid))
cfd.plot()

# %% [markdown]
# **Explanation:** From ntlk corpus import the names package. Then pass the data into the conditial frequency distribution method to get the field ids with their counts where each field id is nothing but the 26 letters in the English language. We then plot it to have the records for male and female represented for each of those field ids.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 2.5 Use the Gutenberg Corpus module to explore austen-persuasion.txt. Write a function to find out the 20 most frequent occurring words of this text file that are not stopwords. Please get rid of numbers and punctuations.  Please make sure we are not double-counting words like “This” and “this”, which differ only in capitalization.

# %%
text = gutenberg.words('austen-persuasion.txt')

# %%
def most_freq_words(text):
    fdist = FreqDist(w.lower() for w in text if w.isalpha() and w.lower() not in stopwords.words('english'))
    return fdist.most_common(20)

most_freq_words(text)
# Out:
# [('anne', 497),
#  ('could', 451),
#  ('would', 355),
#  ('captain', 303),
#  ('mrs', 291),
#  ('elliot', 289),
#  ('mr', 256),
#  ('one', 238),
#  ('must', 228),
#  ('wentworth', 218),
#  ('lady', 216),
#  ('much', 205),
#  ('good', 187),
#  ('little', 176),
#  ('said', 173),
#  ('charles', 166),
#  ('might', 166),
#  ('well', 163),
#  ('never', 155),
#  ('time', 152)]

# %% [markdown]
# **Explanation:** Call the file mentioned in the question and store the words in a variable. Then write a function that can find the frequency fo the top 20 words. The conditions we will needs inside the FreqDist() method is that the words must be lower case and are alphabets only which are not stopwords. The flow of which can be seen from the above code. Then use the most common method to pass a number as an argument which is basically the number of words we wish to run this fucntion for.

# %% [markdown]
# ----

# %% [markdown]
# #### Question 2.6 Use one of the path similarity measures to score the similarity of each of the following pairs of words. Rank the pairs in order of decreasing similarity: car-automobile,  journey-voyage, boy-lad, coast-shore,  midday-noon, furnace-stove, food-fruit, bird-cock, bird-crane, tool-implement,   journey-car,  cemetery-woodland, food-rooster, coast-hill, forest-graveyard, shore-woodland, coast-forest, lad-wizard, chord-smile, glass-magician, noon-string.

# %%
from nltk.corpus import wordnet as wn

# %%
pairs = [('car', 'automobile'), ('journey', 'voyage'), ('boy', 'lad'), ('coast', 'shore'), ('midday', 'noon'), 
         ('furnace', 'stove'), ('food', 'fruit'), ('bird', 'cock'), ('bird', 'crane'), ('tool', 'implement'),
         ('journey', 'car'),('cemetery', 'woodland'), ('food', 'rooster'), ('coast', 'hill'), ('forest', 'graveyard'),
         ('shore', 'woodland'), ('coast', 'forest'), ('lad', 'wizard'), ('chord', 'smile'),
         ('glass', 'magician'), ('noon', 'string')]

# %%
from operator import itemgetter

# %%
path = []
for w1, w2 in pairs:
    path.append((w1, w2, wn.path_similarity(wn.synsets(w1)[0], wn.synsets(w2)[0])))
sorted(path,key=itemgetter(2),reverse=True)
# Out:
# [('car', 'automobile', 1.0),
#  ('midday', 'noon', 1.0),
#  ('coast', 'shore', 0.5),
#  ('tool', 'implement', 0.5),
#  ('boy', 'lad', 0.3333333333333333),
#  ('journey', 'voyage', 0.25),
#  ('coast', 'hill', 0.2),
#  ('shore', 'woodland', 0.2),
#  ('lad', 'wizard', 0.2),
#  ('bird', 'crane', 0.1111111111111111),
#  ('cemetery', 'woodland', 0.1111111111111111),
#  ('glass', 'magician', 0.1111111111111111),
#  ('food', 'fruit', 0.09090909090909091),
#  ('coast', 'forest', 0.09090909090909091),
#  ('chord', 'smile', 0.09090909090909091),
#  ('furnace', 'stove', 0.07692307692307693),
#  ('forest', 'graveyard', 0.07142857142857142),
#  ('bird', 'cock', 0.0625),
#  ('food', 'rooster', 0.0625),
#  ('noon', 'string', 0.058823529411764705),
#  ('journey', 'car', 0.05)]

# %% [markdown]
# **Explanation:** I create an arry for each pair and then we compare the path similarity for the pairs based on synsets for word 1 on word 2 and then put the results in decreasing order using sorted method.

# %% [markdown]
# ----
